# %% [markdown]
# # 1. TF - Binding

# %% [markdown]
# # 1.1 Setup

# %% [markdown]
# # 1.2 Lambert

# %%
lambert_url = "http://humantfs.ccbr.utoronto.ca/download/v_1.01/TF_names_v_1.01.txt"
lambert_out = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/lambert.csv"

# %%
# !wget --no-check-certificate --no-verbose '{lambert_url}' -O {lambert_out}

# %% [markdown]
# # 1.3 ChipAtlas

# %%
import subprocess

# === Define variables ===
params_mta = "https://chip-atlas.dbcls.jp/data/metadata/experimentList.tab"  # Replace with {params.mta}
output_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/chipatlas_meta.tsv"                   # Replace with {output}
input_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/lambert.csv"                        # Replace with {input}

# 1️⃣ Download the file
print("Downloading file...")
subprocess.run(
    ["wget", "--no-verbose", params_mta, "-O", output_file],
    check=True
)

# 2️⃣ Run the Python script
print("Processing downloaded data...")
result = subprocess.run(
    ["python", "/home/andrem/GRN-project/resources/greta/tfb/chipatlas_meta.py", output_file, input_file],
    capture_output=True, text=True
)

# Print stdout and stderr
print("STDOUT:")
print(result.stdout)
print("STDERR:")
print(result.stderr)

# %%
keywords = [
    "B-Cell",
    "B-cell (CD19+)",
    "Bone Marrow Cells",
    "Bone marrow mononuclear cells",
    "Bone marrow nuclear cells",
    "CD20+ B cells",
    "CD4+ T cells",
    "CD8+ T cells",
    "Dendritic Cells",
    "Macrophages",
    "Mast Cells",
    "Memory B cells",
    "Memory T cells",
    "Monocytes",
    "Monocytes-CD14+",
    "Naive B cells",
    "Natural Killer T-Cells",
    "Natural killer cells",
    "T cells",
    "Th1 Cells",
    "Th17 Cells",
    "Th2 Cells",
    "Treg",
    "bone",
    "blood",
    "hematopoiesis",
    "haematopoiesis",
    "hematopoietic",
    "haematopoietic",
    "bone-marrow",
    "leukemia",
    "acute myeloid leukemia",
    "AML",
    "myeloid",
    "monocytic",
    "promyelocytic",
    "granulocytic",
    "erythroid",
    "megakaryocytic",
    "hematopoietic stem cell",
    "HSC",
    "LSC",
    "progenitor cell",
    "CD34+",
    "CD33+",
    "CD13+",
    "FLT3",
    "NPM1",
    "KIT",
    "RUNX1",
    "CEBPA",
    "blast cell",
    "immature myeloid cell",
    "AML cell line",
    "MV4-11",
    "MOLM-13",
    "MOLM-14",
    "THP-1",
    "HL-60",
    "KG-1",
    "OCI-AML2",
    "OCI-AML3",
    "NB4",
    "Kasumi-1",
    "PL-21",
    "SKM-1",
    "U937"
]

# %%
import pandas as pd

chipatlas_meta = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/chipatlas_meta.tsv"
output = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/chipatlas_meta_filtered.tsv"

df_hg38 = pd.read_csv(chipatlas_meta, sep='\t', header=None)

# Filter by keywords (case-insensitive)
keyword_mask = df_hg38.apply(lambda row: any(
    kw in str(row[2]).lower()
    for kw in keywords
), axis=1)

df_filtered = df_hg38[keyword_mask]

print(f"Total records after filtering: {len(df_filtered)}")

df_filtered.to_csv(output, sep='\t', index=False, header=None)
print(f"Filtered metadata saved to: {output}")

# %%
import os
import subprocess

# Assuming output_dir and df_filtered are defined earlier
meta_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/chipatlas_meta_filtered.tsv"
max_psize = 750

# Use the correct index for TF names
unique_tfs = df_filtered[1].dropna().unique()

raw_dir = os.path.join(output_dir, 'chipatlas_raw')
os.makedirs(raw_dir, exist_ok=True)

# Loop over each transcription factor
for tf in unique_tfs:
    url = f"https://chip-atlas.dbcls.jp/data/hg38/assembled/Oth.ALL.50.{tf}.AllCell.bed"
    output = os.path.join(raw_dir, f"{tf}.bed")

    #Build the command string
    command = (
        f"bash /home/andrem/GRN-project/workflow/bash_scripts/chipatlas.sh "
        f"\"{url}\" \"{output}\" \"{meta_file}\" \"{max_psize}\""
    )

    print(f"Running for {output}...")
    try:
        subprocess.run(command, shell=True, check=True)
    except subprocess.CalledProcessError as e:
        print(f"Error processing {output}: {e}")

# %%
import os
import subprocess

bed_dir = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/chipatlas_raw"
output = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/chipatlas.bed"

command = (
    f"bash /home/andrem/GRN-project/workflow/bash_scripts/aggreagate_chipatlas.sh "
    f"\"{bed_dir}\" \"{output}\""
)

try:
    subprocess.run(command, shell=True, check=True)
except subprocess.CalledProcessError as e:
    print(f"Error processing {output}: {e}")

# %% [markdown]
# # 2. ReMap2022

# %% [markdown]
# # 2.1 BTO

# %%
import subprocess

params_url = "'https://service.tib.eu/ts4tib/api/ontologies/bto/download'"  # Replace with {params.url}
output_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/bto.tsv"                      # Replace with {output}

command = f"wget --no-verbose '{params_url}' -O - | python /home/andrem/GRN-project/resources/greta/tfb/bto.py '{output_file}'"
result = subprocess.run(command, shell=True, capture_output=True, text=True)

print("STDOUT:")
print(result.stdout)
print("STDERR:")
print(result.stderr)

# %%
import subprocess

mta_url = "https://remap.univ-amu.fr/storage/remap2022/biotypes/remap2022_hsap_biotypes.xlsx"  # Replace with {params.mta}
input_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/bto.tsv"            # Replace with {input}
output_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/remap2022meta.tsv"          # Replace with {output}

command = f"wget --no-verbose '{mta_url}' -O - | python /home/andrem/GRN-project/resources/greta/tfb/remap2022_meta.py '{input_file}' '{output_file}'"
result = subprocess.run(command, shell=True, capture_output=True, text=True)

print("STDOUT:")
print(result.stdout)
print("STDERR:")
print(result.stderr)

# %%
import os
import subprocess

# Replace these with actual values:
params_url = "https://remap.univ-amu.fr/storage/remap2022/hg38/MACS2/remap2022_nr_macs2_hg38_v1_0.bed.gz"  # Replace with {params.url}
output_dir = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/remap2022_raw"                # Replace with {output}
output_tmp = f"{output_dir}.tmp"
input_tfs = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/lambert.csv"               # Replace with {input.tfs}
input_mta = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/remap2022meta.tsv"               # Replace with {input.mta}
max_psize = "750"                             # Replace with {params.max_psize}

# 1️⃣ Create the output directory
os.makedirs(output_dir, exist_ok=True)

# 2️⃣ Download the file
print("Downloading file...")
subprocess.run(
    ["wget", "--no-verbose", params_url, "-O", output_tmp],
    check=True
)

# 3️⃣ Unzip and pipe to the Python script
print("Processing data...")
command = (
    f"zcat {output_tmp} | "
    f"python /home/andrem/GRN-project/resources/greta/tfb/remap2022_raw.py "
    f"{input_tfs} {input_mta} {max_psize} {output_dir}"
)
result = subprocess.run(command, shell=True, capture_output=True, text=True)

print("STDOUT:")
print(result.stdout)
print("STDERR:")
print(result.stderr)

# 4️⃣ Remove the temporary file
print("Cleaning up...")
os.remove(output_tmp)

# %%
import os
import subprocess
import glob

# Define variables
threads = 32
raw_dir = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/remap2022_raw"
output_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/remap2022.bed"

# Step 1: List all .bed files
bed_files = glob.glob(os.path.join(raw_dir, "*.bed"))

# Step 2: Merge each .bed file in parallel
print("Merging .bed files...")
merge_commands = []
for bed_file in bed_files:
    tmp_file = f"{bed_file}.tmp"
    cmd = [
        "bedtools", "merge",
        "-i", bed_file,
        "-c", "4,5",
        "-o", "distinct,distinct"
    ]
    with open(tmp_file, 'w') as out_f:
        result = subprocess.run(cmd, stdout=out_f, stderr=subprocess.PIPE, text=True)
        if result.returncode != 0:
            print(f"Error merging {bed_file}: {result.stderr}")

# Step 3: Concatenate all merged files
print("Aggregating merged files...")
cat_cmd = f"cat {raw_dir}/*.bed.tmp | python /home/andrem/GRN-project/resources/greta/tfb/aggregate.py > {output_file}"
result = subprocess.run(cat_cmd, shell=True, capture_output=True, text=True)
print("STDOUT:")
print(result.stdout)
print("STDERR:")
print(result.stderr)

# Step 4: Remove all .tmp files
print("Cleaning up temporary files...")
for tmp_file in glob.glob(f"{raw_dir}/*.bed.tmp"):
    os.remove(tmp_file)

print(f"Done! Aggregated file: {output_file}")

# %% [markdown]
# # 3. Unibind

# %%
import os
import subprocess

# === Define variables ===
input_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/lambert.csv"  # Replace with actual file path
output_dir = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/unibind_raw"      # Same as {output}
params_url = "https://unibind.uio.no/static/data/20220914/bulk_Robust/Homo_sapiens/hg38_compressed_TFBSs.bed.gz"  # Replace with actual URL
max_psize = "750"                            # Replace with actual value

# 1️⃣ Create output directory
os.makedirs(output_dir, exist_ok=True)

# 2️⃣ Download the compressed file
output_tmp = os.path.join(output_dir, "download.tmp")
print(f"Downloading {params_url} ...")
subprocess.run(
    ["wget", "--no-verbose", params_url, "-O", output_tmp],
    check=True
)

# 3️⃣ Uncompress and pipe to Python script
print("Processing unibind data ...")
command = (
    f"zcat {output_tmp} | "
    f"python /home/andrem/GRN-project/resources/greta/tfb/unibind_raw.py "
    f"{input_file} "
    f"{max_psize} "
    f"{output_dir}"
)
result = subprocess.run(command, shell=True, capture_output=True, text=True)
print("STDOUT:")
print(result.stdout)
print("STDERR:")
print(result.stderr)

# 4️⃣ Delete the temporary file
print("Cleaning up temporary file ...")
os.remove(output_tmp)

print(f"Done! Unibind data processed in {output_dir}")

# %%
import os
import subprocess
import glob

# === Define variables ===
threads = 32
raw_dir = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/unibind_raw"
output_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/unibind.bed"

# 1️⃣ List all .bed files
bed_files = glob.glob(os.path.join(raw_dir, "*.bed"))

# 2️⃣ Merge each .bed file
print("Merging .bed files...")
for bed_file in bed_files:
    tmp_file = f"{bed_file}.tmp"
    cmd = [
        "bedtools", "merge",
        "-i", bed_file,
        "-c", "4,5",
        "-o", "distinct,distinct"
    ]
    with open(tmp_file, 'w') as out_f:
        result = subprocess.run(cmd, stdout=out_f, stderr=subprocess.PIPE, text=True)
        if result.returncode != 0:
            print(f"Error merging {bed_file}: {result.stderr}")

# 3️⃣ Concatenate all .tmp files and aggregate
print("Aggregating merged files...")
cat_cmd = f"cat {raw_dir}/*.bed.tmp | python /home/andrem/GRN-project/resources/greta/tfb/aggregate.py > {output_file}"
result = subprocess.run(cat_cmd, shell=True, capture_output=True, text=True)

print("STDOUT:")
print(result.stdout)
print("STDERR:")
print(result.stderr)

# 4️⃣ Remove all .tmp files
print("Cleaning up temporary files...")
for tmp_file in glob.glob(f"{raw_dir}/*.bed.tmp"):
    os.remove(tmp_file)

print(f"Done! Aggregated file: {output_file}")

# %% [markdown]
# # 4. Merge

# %%
remap_filter_keywords = [
    "osteoblastoma cell",
    "astroblast",
    "blast cell",
    "blastoderm",
    "blastospore",
    "glioblastoma cell",
    "hematopoietic cell",
    "leukemia cell",
    "myeloid leukemia cell line",
    "chronic myeloid leukemia cell",
    "chronic myeloid leukemia cell line",
    "acute myeloid leukemia cell",
    "acute myeloid leukemia cell line",
    "monocyte",
    "monocytic leukemia cell",
    "monocytic leukemia cell line",
    "myeloid progenitor cell",
    "myeloblast",
    "promyelocyte",
    "erythroleukemia cell",
    "erythroleukemia cell line",
    "megakaryocyte",
    "granulocyte",
    "bone marrow",
    "bone marrow cell",
    "bone marrow-derived dendritic cell",
    "bone marrow-derived macrophage",
    "stem cell",
    "hematopoietic stem cell",
    "mesenchymal stem cell",
    "peripheral blood stem cell",
    "dendritic cell",
    "macrophage",
    "myelomonocytic leukemia cell line",
    "hairy cell leukemia cell",
    "hairy cell leukemia cell line",
    "myeloid cell",
    "promyelocytic leukemia cell",
    "promyelocytic leukemia cell line",
    "promonocytic leukemia cell",
    "promonocytic leukemia cell line",
    "megakaryoblastic leukemia cell",
    "megakaryoblastic leukemia cell line",
    "AML cell",
    "CD34+ cell",
    "MLL cell line",
    "MLL leukemia cell line",
    "neoblast",
    "lymphoblast",
    "lymphoblastic leukemia cell",
    "lymphoblastic leukemia cell line",
    "lymphocyte",
    "lymphocytic leukemia cell",
    "lymphocytic leukemia cell line",
    "lymphoid progenitor cell",
    "NK cell",
    "natural killer cell",
    "bone marrow stromal cell",
    "bone marrow stromal cell line",
    "immune stem cell",
    "hematopoietic cell line",
    "peripheral blood monocyte",
    "myeloblastoma cell",
    "myeloid cell line",
    "myeloid dendritic cell",
    "myeloblastoma cell line",
    "myeloblast cell line",
    "myelomonocytic cell line",
    "leukemic stem cell",
    "megakaryocyte cell line",
    "erythroid progenitor cell",
    "erythroblast",
    "erythroblast cell line",
    "megakaryocytic leukemia cell",
    "megakaryocytic leukemia cell line",
    "basophilic leukemia cell",
    "basophilic leukemia cell line",
    "eosinophilic leukemia cell",
    "eosinophilic leukemia cell line",
    "granulocytic leukemia cell",
    "granulocytic leukemia cell line",
    "regulatory T-lymphocyte",
    "T-lymphocyte",
    "helper T-lymphocyte",
    "CD4+ cell",
    "CD8+ cell",
    "lymphoid dendritic cell",
    "macrophage foam cell",
    "peritoneal macrophage",
    "alveolar macrophage",
    "alveolar macrophage cell line",
    "monocyte-derived dendritic cell",
    "monocyte-derived macrophage",
    "monocyte cell line",
    "peripheral blood lymphocyte",
    "leukocyte",
    "large granular lymphocyte",
    "acute promyelocytic leukemia cell",
    "acute promyelocytic leukemia cell line",
    "chronic lymphocytic leukemia cell",
    "chronic lymphocytic leukemia cell line",
    "acute lymphoblastic leukemia cell",
    "acute lymphoblastic leukemia cell line",
    "B-cell leukemia cell",
    "B-cell chronic lymphocytic leukemia cell",
    "B-cell acute lymphoblastic leukemia cell",
    "T-cell acute lymphoblastic leukemia cell",
    "T-cell chronic lymphocytic leukemia cell",
    "NK-cell leukemia cell",
    "lymphocytic leukemia cell",
    "lymphocytic leukemia cell line",
    "myeloid leukemia cell",
    "myeloid leukemia cell line",
    "erythroleukemia cell",
    "erythroleukemia cell line",
    "leukemic stem cell line",
    "leukemic progenitor cell",
    "hematopoietic progenitor cell",
    "myeloid progenitor cell line",
    "granulocyte progenitor cell",
    "macrophage progenitor cell",
    "monocyte progenitor cell",
    "megakaryocyte progenitor cell",
    "erythroid progenitor cell line",
    "pluripotent hematopoietic stem cell",
    "multipotent hematopoietic stem cell",
    "common myeloid progenitor cell",
    "common lymphoid progenitor cell",
    "pro-B-lymphocyte",
    "pre-B-lymphocyte",
    "pro-T-lymphocyte",
    "pre-T-lymphocyte",
    "monoblast",
    "megakaryoblast",
    "myeloblast cell line",
    "myeloblast cell",
    "myeloid blast cell",
    "myeloid blast cell line",
    "promonocyte",
    "promonocyte cell line",
    "AML blast cell",
    "AML blast cell line",
    "myeloid leukemia blast cell",
    "myeloid leukemia blast cell line",
    "myeloid leukemia cell line",
    "myeloid leukemia cell",
    "myeloid blast cell",
    "myeloid blast cell line",
    "granulocytic blast cell",
    "granulocytic blast cell line",
    "megakaryocytic blast cell",
    "megakaryocytic blast cell line",
    "erythrocytic blast cell",
    "erythrocytic blast cell line",
    "dendritic cell line",
    "monocyte cell",
    "monocyte cell line",
    "monoblast cell",
    "monoblast cell line",
    "myelomonocyte cell",
    "myelomonocyte cell line",
    "peripheral blood stem cell",
    "myeloid-derived suppressor cell",
    "HL-60 cell",
    "NB4 cell",
    "THP-1 cell",
    "KG-1 cell",
    "MV4-11 cell",
    "OCI-AML3 cell",
    "Kasumi-1 cell",
    "U937 cell",
    "K-562 cell",
    "B-cell", "CD4", "CD4-pos", "CD8", "T-cell", "Th1", "Th17", "macrophage", "monocyte", "peripheral-blood-mononuclear-cell", "primary-B-cell", "primary-monocyte"
]

# %%
# Input and output file paths
input_bed_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/remap2022.bed"  # replace with your .bed file path
output_bed_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/remap2022_filtered.bed"

# Read the BED file (no header assumed)
bed_df = pd.read_csv(input_bed_file, sep="\t", header=None, comment="#")

# Rename columns for clarity
bed_df.columns = ["chrom", "start", "end", "tf", "tissue"]

# Filter rows where the 'tissue' column contains any of the remap_filter_keywords
pattern = "|".join(remap_filter_keywords)
filtered_bed_df = bed_df[bed_df["tissue"].str.contains(pattern, case=False, na=False)]

# Write the filtered output
filtered_bed_df.to_csv(output_bed_file, sep="\t", header=False, index=False)

print(f"Filtered BED file saved to: {output_bed_file}")

# %%
unibind_filter_keywords = [
    "osteoblastoma cell",
    "astroblast",
    "blast cell",
    "blastoderm",
    "blastospore",
    "glioblastoma cell",
    "hematopoietic cell",
    "leukemia cell",
    "myeloid leukemia cell line",
    "chronic myeloid leukemia cell",
    "chronic myeloid leukemia cell line",
    "acute myeloid leukemia cell",
    "acute myeloid leukemia cell line",
    "monocyte",
    "monocytic leukemia cell",
    "monocytic leukemia cell line",
    "myeloid progenitor cell",
    "myeloblast",
    "promyelocyte",
    "erythroleukemia cell",
    "erythroleukemia cell line",
    "megakaryocyte",
    "granulocyte",
    "bone marrow",
    "bone marrow cell",
    "bone marrow-derived dendritic cell",
    "bone marrow-derived macrophage",
    "stem cell",
    "hematopoietic stem cell",
    "mesenchymal stem cell",
    "peripheral blood stem cell",
    "dendritic cell",
    "macrophage",
    "myelomonocytic leukemia cell line",
    "hairy cell leukemia cell",
    "hairy cell leukemia cell line",
    "myeloid cell",
    "promyelocytic leukemia cell",
    "promyelocytic leukemia cell line",
    "promonocytic leukemia cell",
    "promonocytic leukemia cell line",
    "megakaryoblastic leukemia cell",
    "megakaryoblastic leukemia cell line",
    "AML cell",
    "CD34+ cell",
    "MLL cell line",
    "MLL leukemia cell line",
    "neoblast",
    "lymphoblast",
    "lymphoblastic leukemia cell",
    "lymphoblastic leukemia cell line",
    "lymphocyte",
    "lymphocytic leukemia cell",
    "lymphocytic leukemia cell line",
    "lymphoid progenitor cell",
    "NK cell",
    "natural killer cell",
    "bone marrow stromal cell",
    "bone marrow stromal cell line",
    "immune stem cell",
    "hematopoietic cell line",
    "peripheral blood monocyte",
    "myeloblastoma cell",
    "myeloid cell line",
    "myeloid dendritic cell",
    "myeloblastoma cell line",
    "myeloblast cell line",
    "myelomonocytic cell line",
    "leukemic stem cell",
    "megakaryocyte cell line",
    "erythroid progenitor cell",
    "erythroblast",
    "erythroblast cell line",
    "megakaryocytic leukemia cell",
    "megakaryocytic leukemia cell line",
    "basophilic leukemia cell",
    "basophilic leukemia cell line",
    "eosinophilic leukemia cell",
    "eosinophilic leukemia cell line",
    "granulocytic leukemia cell",
    "granulocytic leukemia cell line",
    "regulatory T-lymphocyte",
    "T-lymphocyte",
    "helper T-lymphocyte",
    "CD4+ cell",
    "CD8+ cell",
    "lymphoid dendritic cell",
    "macrophage foam cell",
    "peritoneal macrophage",
    "alveolar macrophage",
    "alveolar macrophage cell line",
    "monocyte-derived dendritic cell",
    "monocyte-derived macrophage",
    "monocyte cell line",
    "peripheral blood lymphocyte",
    "leukocyte",
    "large granular lymphocyte",
    "acute promyelocytic leukemia cell",
    "acute promyelocytic leukemia cell line",
    "chronic lymphocytic leukemia cell",
    "chronic lymphocytic leukemia cell line",
    "acute lymphoblastic leukemia cell",
    "acute lymphoblastic leukemia cell line",
    "B-cell leukemia cell",
    "B-cell chronic lymphocytic leukemia cell",
    "B-cell acute lymphoblastic leukemia cell",
    "T-cell acute lymphoblastic leukemia cell",
    "T-cell chronic lymphocytic leukemia cell",
    "NK-cell leukemia cell",
    "lymphocytic leukemia cell",
    "lymphocytic leukemia cell line",
    "myeloid leukemia cell",
    "myeloid leukemia cell line",
    "erythroleukemia cell",
    "erythroleukemia cell line",
    "leukemic stem cell line",
    "leukemic progenitor cell",
    "hematopoietic progenitor cell",
    "myeloid progenitor cell line",
    "granulocyte progenitor cell",
    "macrophage progenitor cell",
    "monocyte progenitor cell",
    "megakaryocyte progenitor cell",
    "erythroid progenitor cell line",
    "pluripotent hematopoietic stem cell",
    "multipotent hematopoietic stem cell",
    "common myeloid progenitor cell",
    "common lymphoid progenitor cell",
    "pro-B-lymphocyte",
    "pre-B-lymphocyte",
    "pro-T-lymphocyte",
    "pre-T-lymphocyte",
    "monoblast",
    "megakaryoblast",
    "myeloblast cell line",
    "myeloblast cell",
    "myeloid blast cell",
    "myeloid blast cell line",
    "promonocyte",
    "promonocyte cell line",
    "AML blast cell",
    "AML blast cell line",
    "myeloid leukemia blast cell",
    "myeloid leukemia blast cell line",
    "myeloid leukemia cell line",
    "myeloid leukemia cell",
    "myeloid blast cell",
    "myeloid blast cell line",
    "granulocytic blast cell",
    "granulocytic blast cell line",
    "megakaryocytic blast cell",
    "megakaryocytic blast cell line",
    "erythrocytic blast cell",
    "erythrocytic blast cell line",
    "dendritic cell line",
    "monocyte cell",
    "monocyte cell line",
    "monoblast cell",
    "monoblast cell line",
    "myelomonocyte cell",
    "myelomonocyte cell line",
    "peripheral blood stem cell",
    "myeloid-derived suppressor cell",
    "HL-60 cell",
    "NB4 cell",
    "THP-1 cell",
    "KG-1 cell",
    "MV4-11 cell",
    "OCI-AML3 cell",
    "Kasumi-1 cell",
    "U937 cell",
    "K-562 cell",
    "B-cell", "CD4", "CD4-pos", "CD8", "T-cell", "Th1", "Th17", "macrophage", "monocyte", "peripheral-blood-mononuclear-cell", "primary-B-cell", "primary-monocyte",
    "leukemia", "myeloid", "monocytic", "promyelocytic", "granulocytic", "erythroid", "megakaryocytic", "hematopoietic stem cell", "HSC", "LSC", "progenitor cell",
]

# %%
# Input and output file paths
input_bed_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/unibind.bed"  # replace with your .bed file path
output_bed_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/unibind_filtered.bed"

# Read the BED file (no header assumed)
bed_df = pd.read_csv(input_bed_file, sep="\t", header=None, comment="#")

# Rename columns for clarity
bed_df.columns = ["chrom", "start", "end", "tf", "tissue"]

# Filter rows where the 'tissue' column contains any of the remap_filter_keywords
pattern = "|".join(unibind_filter_keywords)
filtered_bed_df = bed_df[bed_df["tissue"].str.contains(pattern, case=False, na=False)]

# Write the filtered output
filtered_bed_df.to_csv(output_bed_file, sep="\t", header=False, index=False)

print(f"Filtered BED file saved to: {output_bed_file}")

# %%
import subprocess
import os

# Define your .bed files
bed_files = [
    "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/chipatlas.bed",
    "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/remap2022_filtered.bed",
    "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/unibind_filtered.bed"
]

# Output paths
concatenated_bed = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/concatenated.bed"
no_celltype_bed = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/concatenated_no_celltype.bed"
sorted_bed = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/sorted_no_celltype.bed"
merged_bed = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/dbs/merged.bed"

# Concatenate the files
with open(concatenated_bed, "w") as outfile:
    for bed_file in bed_files:
        with open(bed_file, "r") as infile:
            for line in infile:
                outfile.write(line)

# Remove the fifth column (cell type)
with open(concatenated_bed, "r") as infile, open(no_celltype_bed, "w") as outfile:
    for line in infile:
        fields = line.strip().split("\t")
        outfile.write("\t".join(fields[:4]) + "\n")

# Sort the BED file by chrom, start, end, and TF (bedtools sort can only sort by chrom/start/end)
# We will use Unix sort instead to also sort by TF
subprocess.run(
    f'sort -k1,1 -k2,2n -k3,3n -k4,4 {no_celltype_bed} > {sorted_bed}',
    shell=True,
    check=True
)

# Group by chrom, TF, and merge overlapping regions
# Here: -g 1,4 groups by chromosome and TF
# -c 2,3 merges overlapping regions using min(start) and max(end)
subprocess.run(
    f'bedtools groupby -i {sorted_bed} -g 1,4 -c 2,3 -o min,max > {merged_bed}',
    shell=True,
    check=True
)

print(f"Final merged BED file saved to: {merged_bed}")

# %% [markdown]
# -------

# %% [markdown]
# -------

# %% [markdown]
# # 2. TF Activity

# %%
meta_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-actvity/knockTF_meta.csv"
data_file = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-actvity/knockTF_expr.csv"
out_dir = "/data/benchmarks/andrem/data/pAML/benchmarks/tf-actvity"

# %%
import pandas as pd

# Read the CSV file
meta_df = pd.read_csv(meta_file)

# Rename the first column if it was read as 'Unnamed: 0' or empty
if meta_df.columns[0] == '' or meta_df.columns[0].startswith('Unnamed'):
    meta_df.rename(columns={meta_df.columns[0]: 'Dataset ID'}, inplace=True)

allowed_tissues = [
    "Blood", 
    "Haematopoietic_and_lymphoid_tissue", 
    "Haematopoietic_and_lymphoid_tissue_Blood", 
    "Bone_marrow",
    "Leukemia",
    "osteoblastoma cell",
    "astroblast",
    "blast cell",
    "blastoderm",
    "blastospore",
    "glioblastoma cell",
    "hematopoietic cell",
    "leukemia cell",
    "myeloid leukemia cell line",
    "chronic myeloid leukemia cell",
    "chronic myeloid leukemia cell line",
    "acute myeloid leukemia cell",
    "acute myeloid leukemia cell line",
    "monocyte",
    "monocytic leukemia cell",
    "monocytic leukemia cell line",
    "myeloid progenitor cell",
    "myeloblast",
    "promyelocyte",
    "erythroleukemia cell",
    "erythroleukemia cell line",
    "megakaryocyte",
    "granulocyte",
    "bone marrow",
    "bone marrow cell",
    "bone marrow-derived dendritic cell",
    "bone marrow-derived macrophage",
    "stem cell",
    "hematopoietic stem cell",
    "mesenchymal stem cell",
    "peripheral blood stem cell",
    "dendritic cell",
    "macrophage",
    "myelomonocytic leukemia cell line",
    "hairy cell leukemia cell",
    "hairy cell leukemia cell line",
    "myeloid cell",
    "promyelocytic leukemia cell",
    "promyelocytic leukemia cell line",
    "promonocytic leukemia cell",
    "promonocytic leukemia cell line",
    "megakaryoblastic leukemia cell",
    "megakaryoblastic leukemia cell line",
    "AML cell",
    "CD34+ cell",
    "MLL cell line",
    "MLL leukemia cell line",
    "neoblast",
    "lymphoblast",
    "lymphoblastic leukemia cell",
    "lymphoblastic leukemia cell line",
    "lymphocyte",
    "lymphocytic leukemia cell",
    "lymphocytic leukemia cell line",
    "lymphoid progenitor cell",
    "NK cell",
    "natural killer cell",
    "bone marrow stromal cell",
    "bone marrow stromal cell line",
    "immune stem cell",
    "hematopoietic cell line",
    "peripheral blood monocyte",
    "myeloblastoma cell",
    "myeloid cell line",
    "myeloid dendritic cell",
    "myeloblastoma cell line",
    "myeloblast cell line",
    "myelomonocytic cell line",
    "leukemic stem cell",
    "megakaryocyte cell line",
    "erythroid progenitor cell",
    "erythroblast",
    "erythroblast cell line",
    "megakaryocytic leukemia cell",
    "megakaryocytic leukemia cell line",
    "basophilic leukemia cell",
    "basophilic leukemia cell line",
    "eosinophilic leukemia cell",
    "eosinophilic leukemia cell line",
    "granulocytic leukemia cell",
    "granulocytic leukemia cell line",
    "regulatory T-lymphocyte",
    "T-lymphocyte",
    "helper T-lymphocyte",
    "CD4+ cell",
    "CD8+ cell",
    "lymphoid dendritic cell",
    "macrophage foam cell",
    "peritoneal macrophage",
    "alveolar macrophage",
    "alveolar macrophage cell line",
    "monocyte-derived dendritic cell",
    "monocyte-derived macrophage",
    "monocyte cell line",
    "peripheral blood lymphocyte",
    "leukocyte",
    "large granular lymphocyte",
    "acute promyelocytic leukemia cell",
    "acute promyelocytic leukemia cell line",
    "chronic lymphocytic leukemia cell",
    "chronic lymphocytic leukemia cell line",
    "acute lymphoblastic leukemia cell",
    "acute lymphoblastic leukemia cell line",
    "B-cell leukemia cell",
    "B-cell chronic lymphocytic leukemia cell",
    "B-cell acute lymphoblastic leukemia cell",
    "T-cell acute lymphoblastic leukemia cell",
    "T-cell chronic lymphocytic leukemia cell",
    "NK-cell leukemia cell",
    "lymphocytic leukemia cell",
    "lymphocytic leukemia cell line",
    "myeloid leukemia cell",
    "myeloid leukemia cell line",
    "erythroleukemia cell",
    "erythroleukemia cell line",
    "leukemic stem cell line",
    "leukemic progenitor cell",
    "hematopoietic progenitor cell",
    "myeloid progenitor cell line",
    "granulocyte progenitor cell",
    "macrophage progenitor cell",
    "monocyte progenitor cell",
    "megakaryocyte progenitor cell",
    "erythroid progenitor cell line",
    "pluripotent hematopoietic stem cell",
    "multipotent hematopoietic stem cell",
    "common myeloid progenitor cell",
    "common lymphoid progenitor cell",
    "pro-B-lymphocyte",
    "pre-B-lymphocyte",
    "pro-T-lymphocyte",
    "pre-T-lymphocyte",
    "monoblast",
    "megakaryoblast",
    "myeloblast cell line",
    "myeloblast cell",
    "myeloid blast cell",
    "myeloid blast cell line",
    "promonocyte",
    "promonocyte cell line",
    "AML blast cell",
    "AML blast cell line",
    "myeloid leukemia blast cell",
    "myeloid leukemia blast cell line",
    "myeloid leukemia cell line",
    "myeloid leukemia cell",
    "myeloid blast cell",
    "myeloid blast cell line",
    "granulocytic blast cell",
    "granulocytic blast cell line",
    "megakaryocytic blast cell",
    "megakaryocytic blast cell line",
    "erythrocytic blast cell",
    "erythrocytic blast cell line",
    "dendritic cell line",
    "monocyte cell",
    "monocyte cell line",
    "monoblast cell",
    "monoblast cell line",
    "myelomonocyte cell",
    "myelomonocyte cell line",
    "peripheral blood stem cell",
    "myeloid-derived suppressor cell",
    "HL-60 cell",
    "NB4 cell",
    "THP-1 cell",
    "KG-1 cell",
    "MV4-11 cell",
    "OCI-AML3 cell",
    "Kasumi-1 cell",
    "U937 cell",
    "K-562 cell",
    "B-cell", "CD4", "CD4-pos", "CD8", "T-cell", "Th1", "Th17", "macrophage", "monocyte", "peripheral-blood-mononuclear-cell", "primary-B-cell", "primary-monocyte",
    "leukemia", "myeloid", "monocytic", "promyelocytic", "granulocytic", "erythroid", "megakaryocytic", "hematopoietic stem cell", "HSC", "LSC", "progenitor cell",
]

# Filter the DataFrame
filtered_df = meta_df[
    meta_df["Tissue.Type"].str.lower().isin([t.lower() for t in allowed_tissues])
]

# %%
import os
import pandas as pd

# Read the main data file
df = pd.read_csv(data_file)

# Rename the first column if it was read as 'Unnamed: 0' or empty
if df.columns[0] == '' or df.columns[0].startswith('Unnamed'):
    df.rename(columns={df.columns[0]: 'Dataset ID'}, inplace=True)

# Filter df to only include Dataset IDs present in filtered_df
filtered_ids = filtered_df["Dataset ID"].unique()
df_filtered_by_ids = df[df["Dataset ID"].isin(filtered_ids)]

# Merge the TF column into the filtered data (avoids duplicates by using drop_duplicates)
tf_info = filtered_df[["Dataset ID", "TF"]].drop_duplicates()
df_merged = pd.merge(df_filtered_by_ids, tf_info, on="Dataset ID", how="left")

# %%
# Rename the column
df_merged = df_merged.rename(columns={'TF_y': 'TF_name'})

# Reorder columns to make 'TF_name' the second column
cols = list(df_merged.columns)
cols.remove('TF_name')
cols = [cols[0], 'TF_name'] + cols[1:]
df_merged = df_merged[cols]

# Save the merged DataFrame to CSV
df_merged.to_csv(os.path.join(out_dir, "knock_tf_benchmark_data.csv"), index=False)

# %%
df_merged
# Out:
#          Dataset ID TF_name      A1BG  A1BG-AS1     A1CF  A2LD1       A2M  \
# 0    DataSet_01_004   CREB1 -0.255680  0.111050 -0.28527    0.0 -0.035860
# 1    DataSet_01_005  POU5F1  0.478500 -0.375710 -0.84718    0.0  3.354450
# 2    DataSet_01_012    FLI1  0.000000  0.000000  0.40251    0.0  1.934290
# 3    DataSet_01_014    FLI1  0.000000  0.000000  0.19366    0.0  1.960610
# 4    DataSet_01_015    FLI1  0.000000  0.000000  0.02946    0.0 -3.734240
# ..              ...     ...       ...       ...      ...    ...       ...
# 248  DataSet_04_021   SMAD5 -0.311274 -0.316222  0.00000    0.0  0.000000
# 249  DataSet_04_022   STAT1 -0.252936 -0.313706  0.00000    0.0  0.000000
# 250  DataSet_04_023   XRCC5 -0.352672 -0.067114  0.00000    0.0  3.014950
# 251  DataSet_04_024    YBX1 -0.033285  0.244966  0.00000    0.0  0.000000
# 252  DataSet_04_025  ZNF574 -0.402136 -0.454566  0.00000    0.0 -1.494765
#
#         A2ML1   A4GALT    A4GNT  ...     ZWINT     ZXDA      ZXDB      ZXDC  \
# 0   -0.469700  0.18559 -0.25601  ...  0.000000 -0.39888  0.000000  0.104440
# 1    0.171040 -0.34852 -0.95517  ...  0.000000  0.24849  0.000000 -0.286920
# 2    0.000000  0.53462  0.00000  ...  0.000000  0.00000  0.000000 -0.517350
# 3    0.000000 -0.51895  0.00000  ...  0.000000  0.00000  0.000000  0.016510
# 4    0.000000 -0.05051  0.00000  ...  0.000000  0.00000  0.000000 -1.047700
# ..        ...      ...      ...  ...       ...      ...       ...       ...
# 248 -0.304855  0.00000  0.00000  ...  0.024783  0.00000  0.166650 -0.114845
# 249  0.000000  0.00000  0.00000  ... -0.001144  0.00000  0.420218  0.252221
# 250 -1.536053  0.00000  0.00000  ...  0.447777  0.00000  0.221415 -0.307615
# 251 -0.700440  0.00000  0.00000  ...  0.251406  0.00000  0.288996  0.119108
# 252 -0.652077  0.00000  0.00000  ...  0.488863  0.00000  0.066401  0.141487
#
#        ZYG11A    ZYG11B       ZYX     ZZEF1      ZZZ3  psiTPTE22
# 0   -0.164340  0.191460  0.415610  0.393840  0.127900        0.0
# 1   -0.018150  0.119410  0.077850  0.234740  0.228690        0.0
# 2    0.000000  0.000000  3.028970  0.337220 -0.239700        0.0
# 3    0.000000  0.000000  2.609880  0.306030 -0.200010        0.0
# 4    0.000000  0.000000  1.246170  0.098580  0.730540        0.0
# ..        ...       ...       ...       ...       ...        ...
# 248  0.083749  0.071033 -0.250247  0.002988  0.072450        0.0
# 249  0.073945  0.424413 -0.077209  0.476842  0.576382        0.0
# 250 -0.024420  0.008363  0.131661 -0.244030  0.237252        0.0
# 251 -0.236440 -0.004361  0.178174 -0.118009 -0.027151        0.0
# 252  0.349662 -0.138207  0.238649  0.175727  0.102733        0.0
#
# [253 rows x 21987 columns]

# %% [markdown]
# # 3 Gene Sets

# %% [markdown]
# # 3.1 Setup

# %%
import os
import wget
import pandas as pd
import decoupler as dc

# %% [markdown]
# # 3.1 Downloads

# %%
import pandas as pd
import decoupler as dc
import os

# Define the input variables explicitly
urls = [
    'https://data.broadinstitute.org/gsea-msigdb/msigdb/release/2024.1.Hs/h.all.v2024.1.Hs.symbols.gmt',  # Replace with the actual URL
    'https://data.broadinstitute.org/gsea-msigdb/msigdb/release/2024.1.Hs/c2.cp.kegg_legacy.v2024.1.Hs.symbols.gmt',
    'https://data.broadinstitute.org/gsea-msigdb/msigdb/release/2024.1.Hs/c2.cp.reactome.v2024.1.Hs.symbols.gmt'
]

db_names = [
    'hallmark',
    'kegg',
    'reactome'
]

# Output directory
output_dir = '/data/benchmarks/andrem/data/pAML/benchmarks/gsets'

# Make sure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Loop over each URL and process the gene set
for url, db_name in zip(urls, db_names):
    output_file = os.path.join(output_dir, f'{db_name}.csv')
    temp_file = f'{output_file}.tmp'

    # Download the file using wget
    os.system(f"wget --no-verbose '{url}' -O {temp_file}")

    # Read the gene set file (GMT format)
    gst = dc.read_gmt(temp_file)

    # Clean the 'source' column by removing prefixes
    gst['source'] = ['_'.join(s.split('_')[1:]) for s in gst['source']]

    # Save the processed gene set to CSV
    gst.to_csv(output_file, index=False)

    # Remove the temporary file
    os.remove(temp_file)

# %%
import os
import pandas as pd
import rpy2.robjects as ro
from rpy2.robjects import pandas2ri
from rpy2.robjects.conversion import localconverter

# Define input variables
url = 'https://github.com/saezlab/progeny/raw/master/data/model_human_full.rda'  # Replace with actual URL
output_file = '/data/benchmarks/andrem/data/pAML/benchmarks/gsets/prog.csv'
output_rda = '/data/benchmarks/andrem/data/pAML/benchmarks/gsets/prog.rda'

# Download the RDA file using wget
os.system(f"wget --no-verbose '{url}' -O {output_rda}")

# Load the RDA file
ro.r(f"load('{output_rda}')")

# Extract model_human_full from R
model_human_full = ro.r['model_human_full']

# Convert R dataframe to pandas dataframe using the recommended localconverter context
with localconverter(ro.default_converter + pandas2ri.converter):
    prg = ro.conversion.rpy2py(model_human_full)

# Rename columns
prg = prg.rename(columns={
    'gene': 'target',
    'pathway': 'source',
    'p.value': 'pval'
})

# Select relevant columns
prg = prg[['source', 'target', 'weight', 'pval']]

# Filter by pval < 1e-5
prg = prg[prg['pval'] < 1e-5]

# Filter gene sets with more than 5 targets
n = prg.groupby('source').size()
prg = prg[prg['source'].isin(n[n > 5].index)]

# Sort the results
prg = prg.sort_values(['source', 'target', 'weight'])

# Save the final CSV
prg.to_csv(output_file, index=False)

# Clean up
os.remove(output_rda)

# %%
import pandas as pd

# Define your 4 CSV file paths
files = [
    '/data/benchmarks/andrem/data/pAML/benchmarks/gsets/hallmark.csv',
    '/data/benchmarks/andrem/data/pAML/benchmarks/gsets/kegg.csv',
    '/data/benchmarks/andrem/data/pAML/benchmarks/gsets/prog.csv',
    '/data/benchmarks/andrem/data/pAML/benchmarks/gsets/reactome.csv'
]

# Save to a new CSV file
output_file = '/data/benchmarks/andrem/data/pAML/benchmarks/gsets/merged_network.csv'

# Initialize an empty list to hold the DataFrames
dfs = []

# Loop through each file and process it
for file in files:
    df = pd.read_csv(file)
    
    # Check if 'source' and 'target' columns exist
    if 'source' in df.columns and 'target' in df.columns:
        df = df[['source', 'target']]
    else:
        raise ValueError(f"File {file} is missing 'source' and/or 'target' columns.")
    
    dfs.append(df)

# Concatenate all DataFrames
merged_df = pd.concat(dfs, ignore_index=True)

# Remove duplicate edges
merged_df = merged_df.drop_duplicates()


merged_df.to_csv(output_file, index=False)

print(f"Merged network saved to: {output_file}")

# %% [markdown]
# # 4. TF Markers

# %%
import os
import subprocess

# ----------------------
# Define variables here:
# ----------------------

# URL to download the zip file from HPA
hpa_url = 'https://www.proteinatlas.org/download/proteinatlas.tsv.zip'  # Replace with the actual URL from config

# Path to the Lambert TFs file
tfs_file = '/data/benchmarks/andrem/data/pAML/benchmarks/tf-binding-test/lambert.csv'  # Replace with the actual path to your TF list

# Output directory and file
output_file = '/data/benchmarks/andrem/data/pAML/benchmarks/tfm/hpa.tsv'  # Replace with the desired output file path
output_zip = output_file + '.zip'

# Path to the processing script (assuming it exists)
processing_script = '/home/andrem/GRN-project/resources/greta/tfm/hpa.py'

# ----------------------
# Execute steps
# ----------------------

# Step 1: Download the HPA zip file
os.system(f"wget --no-verbose '{hpa_url}' -O {output_zip}")

# Step 2: Run the processing script
subprocess.run([
    'python', processing_script,
    '-i', output_zip,
    '-t', tfs_file,
    '-o', output_file
], check=True)

# %%
import os
import pandas as pd

# --------------------------------------
# Define variables explicitly here:
# --------------------------------------

# URL to download the TFMDB file
tfmdb_url = 'https://bio.liclab.net/TF-Marker/public/download/download_TFMarker.csv'  # Replace with the actual URL from config

# Output file path
output_file = '/data/benchmarks/andrem/data/pAML/benchmarks/tfm/tfmdb.tsv'

# --------------------------------------
# Execute steps
# --------------------------------------

# Step 1: Download the TFMDB file
os.system(f"wget --no-verbose '{tfmdb_url}' -O {output_file}")

# Step 2: Process the TFMDB file
df = pd.read_csv(output_file, sep=',')  # Assuming the downloaded file is comma-separated

# Keep only relevant columns
df = df[['Gene Name', 'Cell Name', 'Tissue Type']]

# Create 'ctype' by concatenating Cell Name and Tissue Type
df['ctype'] = df['Cell Name'] + ',' + df['Tissue Type']

# Group by Gene Name and combine ctype values
df = df.groupby('Gene Name', as_index=False)['ctype'].apply(lambda x: ','.join(x))

# Ensure unique ctype values within each gene (remove duplicates)
df['ctype'] = [','.join(sorted(set(s.split(',')))) for s in df['ctype']]

# Drop any duplicates that might remain
df = df.drop_duplicates(['Gene Name', 'ctype'])

# Rename columns for consistency
df = df.rename(columns={'Gene Name': 'gene'})

# Sort by gene and ctype
df = df.sort_values(['gene', 'ctype'])

# Save the processed file
df.to_csv(output_file, sep='\t', index=False, header=None)

# %%
import pandas as pd

# -----------------------------------------
# Define input and output variables here:
# -----------------------------------------

# Paths to the two TSV files
file1 = '/data/benchmarks/andrem/data/pAML/benchmarks/tfm/hpa.tsv'
file2 = '/data/benchmarks/andrem/data/pAML/benchmarks/tfm/tfmdb.tsv'

# Predefined keywords to filter on
keywords = ["B cell", "Dendritic cell", "Lymphoid cell", "Macrophage cell", 
"Macrophages cell", "Macrophagocyte cell", "Mononuclear cell", 
"Natural killer cell", "Peripheral blood cell", "T cell",
"B", "Dendritic cells", "Erythroid cells", "Lymphoid tissue", 
"Macrophages", "Monocytes", "NK", "T", "Leukemia", "Myeloid leukemia",
"Myeloid", "Blood", "Bone Marrow"] 

# Output file
output_file = '/data/benchmarks/andrem/data/pAML/benchmarks/tfm/filtered_tf_markers.txt'

# -----------------------------------------
# Execute steps
# -----------------------------------------

# Read both files
df1 = pd.read_csv(file1, sep='\t', header=None, names=['gene', 'ctype'])
df2 = pd.read_csv(file2, sep='\t', header=None, names=['gene', 'ctype'])

# Concatenate
df = pd.concat([df1, df2], ignore_index=True)

# Filter rows where 'ctype' contains any of the keywords (case-insensitive)
mask = df['ctype'].apply(
    lambda x: any(keyword.lower() in str(x).lower() for keyword in keywords)
)

# Apply the filter
filtered_df = df[mask]

# Keep only the 'gene' column and drop duplicates
filtered_genes = filtered_df['gene'].drop_duplicates()

# Save to output file
filtered_genes.to_csv(output_file, sep='\t', index=False, header=False)

print(f"Filtered TF markers saved to: {output_file}")

# %% [markdown]
# # 5. CRE-Gene

# %% [markdown]
# # 5.1 Metadata

# %%
import requests
import pandas as pd

# === CONFIG ===
meta_url = "https://raw.githubusercontent.com/eQTL-Catalogue/eQTL-Catalogue-resources/master/tabix/tabix_ftp_paths.tsv"
output_path = "/home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/meta.tsv"  # replace with config['dbs']['hg38']['c2g']['eqtlcatalogue']['meta_path']

# === STEP 1: Download metadata ===
print("Downloading metadata...")
r = requests.get(meta_url)
r.raise_for_status()

# Save to a local buffer
with open(output_path, "wb") as f:
    f.write(r.content)

print(f"Metadata downloaded to {output_path}")

# === STEP 2: Filter metadata ===
print("Filtering metadata...")
# The metadata has no header in the awk version, so use generic column names
df = pd.read_csv(output_path, sep="\t", header=None)

# Apply the filter: keep only rows where column 8 (0-based) == "ge"
df = df[df[8] == "ge"]

# Select columns 0, 1, and 5 (these are $1, $2, $6 in awk)
df = df[[0, 1, 5]]

# Write the filtered metadata back
df.to_csv(output_path, sep="\t", index=False, header=False)

print(f"Filtered metadata written to {output_path}")
# Out:
# Downloading metadata...
# Metadata downloaded to /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/meta.tsv
# Filtering metadata...
# Filtered metadata written to /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/meta.tsv

# %%
import pandas as pd

# === CONFIG ===
meta_path = output_path  # Use the same path as above

# === STEP 1: Load metadata ===
df = pd.read_csv(meta_path, sep="\t", header=None, names=["Group", "Dataset", "Tissue"])

# === STEP 2: Get unique tissues ===
unique_tissues = df["Tissue"].dropna().unique()
unique_tissues.sort()

print(f"Found {len(unique_tissues)} unique tissues:\n")
for t in unique_tissues:
    print(t)

# === STEP 3: (Optional) Save to a file ===
with open("unique_tissues.txt", "w") as f:
    for t in unique_tissues:
        f.write(f"{t}\n")
# Out:
# Found 96 unique tissues:
#
# B cell
# CD16+ monocyte
# CD4+ CTL cell
# CD4+ T cell
# CD4+ TCM cell
# CD4+ TEM cell
# CD4+ memory T cell
# CD56+ NK cell
# CD8+ T cell
# CD8+ TCM cell
# CD8+ TEM cell
# LCL
# MAIT cell
# NK cell
# T cell
# Tfh cell
# Th1 cell
# Th17 cell
# Th2 cell
# Treg memory
# Treg naive
# adipose
# adipose (visceral)
# adrenal gland
# artery (aorta)
# artery (coronary)
# artery (tibial)
# astrocyte
# blood
# brain (DLPFC)
# brain (amygdala)
# brain (anterior cingulate cortex)
# brain (caudate)
# brain (cerebellum)
# brain (cortex)
# brain (hippocampus)
# brain (hypothalamus)
# brain (nucleus accumbens)
# brain (putamen)
# brain (spinal cord)
# brain (substantia nigra)
# breast
# cartilage
# dendritic cell
# dnT cell
# dopaminergic neuron
# ependymal cell
# esophagus (gej)
# esophagus (mucosa)
# esophagus (muscularis)
# fibroblast
# floor plate progenitor
# gdT cell
# heart (atrial appendage)
# heart (left ventricle)
# hematopoietic precursor cell
# hepatocyte
# iPSC
# kidney (cortex)
# liver
# lung
# macrophage
# memory B cell
# microglia
# minor salivary gland
# monocyte
# muscle
# neocortex
# neural progenitor
# neuroblast
# neuron
# neutrophil
# ovary
# pancreas
# pancreatic islet
# pituitary
# placenta
# plasmablast
# plasmacytoid dendritic cell
# platelet
# prostate
# sensory neuron
# serotonergic neuron
# sigmoid colon
# skin
# skin (suprapubic)
# small intestine
# spleen
# stomach
# synovium
# testis
# thyroid
# tibial nerve
# transverse colon
# uterus
# vagina

# %%
import pandas as pd
from biomart import BiomartServer

# Connect to Ensembl Biomart
server = BiomartServer("http://www.ensembl.org/biomart")

# Select the Ensembl Genes 111 mart
mart = server.datasets['hsapiens_gene_ensembl']

# Query attributes: Ensembl gene ID and external gene name
response = mart.search({
    'attributes': ['ensembl_gene_id', 'external_gene_name']
})

# Parse result
lines = [line.decode('utf-8').strip().split('\t') for line in response.iter_lines() if line]
df = pd.DataFrame(lines, columns=["id", "symbol"])

# Drop empty symbols
df = df[df["symbol"] != ""]

# Save
out_path = "/home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/ensembl_genes.csv"
df.to_csv(out_path, index=False)
print(f"Saved {len(df)} mappings to {out_path}")
# Out:
# Saved 86364 mappings to /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/ensembl_genes.csv

# %%
import os
import requests
import gzip
import shutil
import pandas as pd
from urllib.parse import quote

# === CONFIG ===
meta_path = "/home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/meta.tsv"
gene_map_path = "/home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/ensembl_genes.csv"  # from gen_gid_ensmbl
output_dir = "/home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw"
pval_threshold = 5e-8
os.makedirs(output_dir, exist_ok=True)

url_template = (
    "http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/"
    "{study_id}/{dataset_id}/{dataset_id}.credible_sets.tsv.gz"
)

interesting_tissues = {
    "B cell", "memory B cell", "plasmablast",
    "T cell", "CD4+ T cell", "CD4+ memory T cell", "CD4+ TEM cell",
    "CD4+ TCM cell", "CD4+ CTL cell", "Th1 cell", "Th2 cell", "Th17 cell",
    "Tfh cell", "Treg naive", "Treg memory",
    "CD8+ T cell", "CD8+ TCM cell", "CD8+ TEM cell",
    "NK cell", "CD56+ NK cell", "MAIT cell", "gdT cell", "dnT cell",
    "monocyte", "CD16+ monocyte", "macrophage",
    "dendritic cell", "plasmacytoid dendritic cell",
    "neutrophil", "platelet",
    "hematopoietic precursor cell", "LCL", "blood"
}

# === Load metadata ===
df = pd.read_csv(meta_path, sep="\t", header=None, names=["StudyID", "DatasetID", "Tissue"])
df_filtered = df[df["Tissue"].isin(interesting_tissues)]
print(f"Found {len(df_filtered)} entries for tissues of interest.")

# === Load Ensembl → symbol map ===
gdict = pd.read_csv(gene_map_path).set_index("id")["symbol"].to_dict()
print(f"Loaded {len(gdict)} gene mappings.")

# === Download & filter ===
for idx, row in df_filtered.iterrows():
    study_id, dataset_id, tissue = row["StudyID"], row["DatasetID"], row["Tissue"]
    url = url_template.format(study_id=study_id, dataset_id=dataset_id)
    out_bed = os.path.join(output_dir, f"{study_id}.{tissue.replace(' ', '_').replace('+', 'plus')}.bed")

    print(f"\nDownloading {tissue} ({study_id}, {dataset_id})")
    print(f"  URL: {url}")
    print(f"  -> {out_bed}")

    try:
        gz_path = out_bed + ".gz"
        with requests.get(url, stream=True, timeout=120) as r:
            r.raise_for_status()
            with open(gz_path, "wb") as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)

        # Decompress and filter
        filtered_out = out_bed + ".filtered"
        with gzip.open(gz_path, "rt") as infile, open(filtered_out, "w") as outfile:
            header = next(infile)  # skip header
            for line in infile:
                parts = line.strip().split("\t")
                if len(parts) < 8:
                    continue
                try:
                    pval = float(parts[7])  # pvalue column
                    if pval <= pval_threshold:
                        coords = parts[3]
                        chrm, start = coords.split("_")[:2]
                        start = end = int(start)
                        gene_id = parts[1]
                        if gene_id in gdict and "_" not in chrm:
                            gene_symbol = gdict[gene_id]
                            sample_name = f"{study_id}.{tissue.replace(' ', '_').replace('+', 'plus')}"
                            outfile.write(f"{chrm}\t{start}\t{end}\t{gene_symbol}\t{sample_name}\n")
                except ValueError:
                    continue
        os.remove(gz_path)
        os.replace(filtered_out, out_bed)

    except Exception as e:
        print(f"❌ Failed for {tissue} ({study_id}, {dataset_id}): {e}")
# Out:
# Found 178 entries for tissues of interest.
# Loaded 86364 gene mappings.
#
# Downloading macrophage (QTS000001, QTD000001)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000001/QTD000001/QTD000001.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000001.macrophage.bed
#
# Downloading macrophage (QTS000001, QTD000006)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000001/QTD000006/QTD000006.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000001.macrophage.bed
#
# Downloading macrophage (QTS000001, QTD000011)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000001/QTD000011/QTD000011.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000001.macrophage.bed
#
# Downloading macrophage (QTS000001, QTD000016)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000001/QTD000016/QTD000016.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000001.macrophage.bed
#
# Downloading monocyte (QTS000002, QTD000021)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000002/QTD000021/QTD000021.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000002.monocyte.bed
#
# Downloading neutrophil (QTS000002, QTD000026)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000002/QTD000026/QTD000026.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000002.neutrophil.bed
#
# Downloading CD4+ T cell (QTS000002, QTD000031)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000002/QTD000031/QTD000031.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000002.CD4plus_T_cell.bed
#
# Downloading Treg memory (QTS000003, QTD000036)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000003/QTD000036/QTD000036.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000003.Treg_memory.bed
#
# Downloading LCL (QTS000006, QTD000056)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000006/QTD000056/QTD000056.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000006.LCL.bed
#
# Downloading LCL (QTS000006, QTD000061)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000006/QTD000061/QTD000061.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000006.LCL.bed
#
# Downloading LCL (QTS000012, QTD000095)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000012/QTD000095/QTD000095.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000012.LCL.bed
#
# Downloading T cell (QTS000012, QTD000105)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000012/QTD000105/QTD000105.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000012.T_cell.bed
#
# Downloading LCL (QTS000013, QTD000110)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000013/QTD000110/QTD000110.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000013.LCL.bed
#
# Downloading LCL (QTS000015, QTD000221)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000015/QTD000221/QTD000221.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000015.LCL.bed
#
# Downloading blood (QTS000015, QTD000356)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000015/QTD000356/QTD000356.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000015.blood.bed
#
# Downloading blood (QTS000019, QTD000373)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000019/QTD000373/QTD000373.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000019.blood.bed
#
# Downloading macrophage (QTS000021, QTD000379)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000021/QTD000379/QTD000379.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000021.macrophage.bed
#
# Downloading macrophage (QTS000021, QTD000384)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000021/QTD000384/QTD000384.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000021.macrophage.bed
#
# Downloading macrophage (QTS000021, QTD000389)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000021/QTD000389/QTD000389.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000021.macrophage.bed
#
# Downloading monocyte (QTS000024, QTD000409)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000024/QTD000409/QTD000409.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000024.monocyte.bed
#
# Downloading monocyte (QTS000024, QTD000414)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000024/QTD000414/QTD000414.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000024.monocyte.bed
#
# Downloading monocyte (QTS000024, QTD000419)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000024/QTD000419/QTD000419.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000024.monocyte.bed
#
# Downloading monocyte (QTS000024, QTD000424)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000024/QTD000424/QTD000424.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000024.monocyte.bed
#
# Downloading monocyte (QTS000024, QTD000429)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000024/QTD000429/QTD000429.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000024.monocyte.bed
#
# Downloading Tfh cell (QTS000026, QTD000439)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000439/QTD000439.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.Tfh_cell.bed
#
# Downloading Th17 cell (QTS000026, QTD000444)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000444/QTD000444.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.Th17_cell.bed
#
# Downloading Th1 cell (QTS000026, QTD000449)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000449/QTD000449.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.Th1_cell.bed
#
# Downloading Th2 cell (QTS000026, QTD000454)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000454/QTD000454.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.Th2_cell.bed
#
# Downloading Th17 cell (QTS000026, QTD000459)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000459/QTD000459.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.Th17_cell.bed
#
# Downloading Treg naive (QTS000026, QTD000464)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000464/QTD000464.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.Treg_naive.bed
#
# Downloading Treg memory (QTS000026, QTD000469)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000469/QTD000469.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.Treg_memory.bed
#
# Downloading B cell (QTS000026, QTD000474)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000474/QTD000474.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.B_cell.bed
#
# Downloading CD4+ T cell (QTS000026, QTD000479)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000479/QTD000479.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000026, QTD000484)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000484/QTD000484.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.CD4plus_T_cell.bed
#
# Downloading CD8+ T cell (QTS000026, QTD000489)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000489/QTD000489.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.CD8plus_T_cell.bed
#
# Downloading CD8+ T cell (QTS000026, QTD000494)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000494/QTD000494.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.CD8plus_T_cell.bed
#
# Downloading CD16+ monocyte (QTS000026, QTD000499)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000499/QTD000499.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.CD16plus_monocyte.bed
#
# Downloading monocyte (QTS000026, QTD000504)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000504/QTD000504.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.monocyte.bed
#
# Downloading NK cell (QTS000026, QTD000509)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000026/QTD000509/QTD000509.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000026.NK_cell.bed
#
# Downloading LCL (QTS000029, QTD000539)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000029/QTD000539/QTD000539.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000029.LCL.bed
#
# Downloading blood (QTS000029, QTD000549)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000029/QTD000549/QTD000549.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000029.blood.bed
#
# Downloading B cell (QTS000036, QTD000585)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000036/QTD000585/QTD000585.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000036.B_cell.bed
#
# Downloading B cell (QTS000036, QTD000586)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000036/QTD000586/QTD000586.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000036.B_cell.bed
#
# Downloading CD4+ T cell (QTS000036, QTD000587)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000036/QTD000587/QTD000587.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000036.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000036, QTD000588)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000036/QTD000588/QTD000588.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000036.CD4plus_T_cell.bed
#
# Downloading CD8+ T cell (QTS000036, QTD000589)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000036/QTD000589/QTD000589.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000036.CD8plus_T_cell.bed
#
# Downloading CD8+ T cell (QTS000036, QTD000590)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000036/QTD000590/QTD000590.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000036.CD8plus_T_cell.bed
#
# Downloading NK cell (QTS000036, QTD000591)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000036/QTD000591/QTD000591.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000036.NK_cell.bed
#
# Downloading NK cell (QTS000036, QTD000592)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000036/QTD000592/QTD000592.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000036.NK_cell.bed
#
# Downloading monocyte (QTS000036, QTD000593)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000036/QTD000593/QTD000593.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000036.monocyte.bed
#
# Downloading monocyte (QTS000036, QTD000594)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000036/QTD000594/QTD000594.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000036.monocyte.bed
#
# Downloading monocyte (QTS000036, QTD000595)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000036/QTD000595/QTD000595.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000036.monocyte.bed
#
# Downloading monocyte (QTS000036, QTD000596)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000036/QTD000596/QTD000596.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000036.monocyte.bed
#
# Downloading B cell (QTS000037, QTD000597)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000037/QTD000597/QTD000597.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000037.B_cell.bed
#
# Downloading NK cell (QTS000037, QTD000598)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000037/QTD000598/QTD000598.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000037.NK_cell.bed
#
# Downloading NK cell (QTS000037, QTD000599)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000037/QTD000599/QTD000599.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000037.NK_cell.bed
#
# Downloading CD4+ T cell (QTS000037, QTD000600)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000037/QTD000600/QTD000600.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000037.CD4plus_T_cell.bed
#
# Downloading CD8+ T cell (QTS000037, QTD000601)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000037/QTD000601/QTD000601.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000037.CD8plus_T_cell.bed
#
# Downloading dendritic cell (QTS000037, QTD000602)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000037/QTD000602/QTD000602.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000037.dendritic_cell.bed
#
# Downloading monocyte (QTS000037, QTD000603)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000037/QTD000603/QTD000603.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000037.monocyte.bed
#
# Downloading CD16+ monocyte (QTS000037, QTD000604)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000037/QTD000604/QTD000604.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000037.CD16plus_monocyte.bed
#
# Downloading plasmacytoid dendritic cell (QTS000037, QTD000605)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000037/QTD000605/QTD000605.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000037.plasmacytoid_dendritic_cell.bed
#
# Downloading B cell (QTS000038, QTD000606)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000606/QTD000606.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.B_cell.bed
#
# Downloading memory B cell (QTS000038, QTD000607)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000607/QTD000607.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.memory_B_cell.bed
#
# Downloading B cell (QTS000038, QTD000608)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000608/QTD000608.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.B_cell.bed
#
# Downloading monocyte (QTS000038, QTD000609)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000609/QTD000609.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.monocyte.bed
#
# Downloading CD16+ monocyte (QTS000038, QTD000610)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000610/QTD000610.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.CD16plus_monocyte.bed
#
# Downloading CD4+ CTL cell (QTS000038, QTD000611)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000611/QTD000611.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.CD4plus_CTL_cell.bed
#
# Downloading CD4+ T cell (QTS000038, QTD000612)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000612/QTD000612.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.CD4plus_T_cell.bed
#
# Downloading CD4+ TCM cell (QTS000038, QTD000613)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000613/QTD000613.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.CD4plus_TCM_cell.bed
#
# Downloading CD4+ TEM cell (QTS000038, QTD000614)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000614/QTD000614.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.CD4plus_TEM_cell.bed
#
# Downloading CD8+ T cell (QTS000038, QTD000615)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000615/QTD000615.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.CD8plus_T_cell.bed
#
# Downloading CD8+ TCM cell (QTS000038, QTD000616)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000616/QTD000616.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.CD8plus_TCM_cell.bed
#
# Downloading CD8+ TEM cell (QTS000038, QTD000617)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000617/QTD000617.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.CD8plus_TEM_cell.bed
#
# Downloading hematopoietic precursor cell (QTS000038, QTD000618)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000618/QTD000618.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.hematopoietic_precursor_cell.bed
#
# Downloading MAIT cell (QTS000038, QTD000619)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000619/QTD000619.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.MAIT_cell.bed
#
# Downloading NK cell (QTS000038, QTD000620)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000620/QTD000620.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.NK_cell.bed
#
# Downloading CD56+ NK cell (QTS000038, QTD000621)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000621/QTD000621.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.CD56plus_NK_cell.bed
#
# Downloading NK cell (QTS000038, QTD000622)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000622/QTD000622.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.NK_cell.bed
#
# Downloading plasmablast (QTS000038, QTD000623)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000623/QTD000623.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.plasmablast.bed
#
# Downloading platelet (QTS000038, QTD000624)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000624/QTD000624.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.platelet.bed
#
# Downloading Treg memory (QTS000038, QTD000625)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000625/QTD000625.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.Treg_memory.bed
#
# Downloading dendritic cell (QTS000038, QTD000626)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000626/QTD000626.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.dendritic_cell.bed
#
# Downloading dnT cell (QTS000038, QTD000627)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000627/QTD000627.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.dnT_cell.bed
#
# Downloading gdT cell (QTS000038, QTD000628)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000628/QTD000628.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.gdT_cell.bed
#
# Downloading plasmacytoid dendritic cell (QTS000038, QTD000629)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000038/QTD000629/QTD000629.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000038.plasmacytoid_dendritic_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000660)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000660/QTD000660.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000661)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000661/QTD000661.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000662)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000662/QTD000662.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000663)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000663/QTD000663.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000664)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000664/QTD000664.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000665)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000665/QTD000665.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000666)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000666/QTD000666.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000667)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000667/QTD000667.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000668)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000668/QTD000668.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000669)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000669/QTD000669.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000670)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000670/QTD000670.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000671)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000671/QTD000671.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000672)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000672/QTD000672.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000673)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000673/QTD000673.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000674)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000674/QTD000674.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000675)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000675/QTD000675.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000676)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000676/QTD000676.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000677)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000677/QTD000677.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000678)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000678/QTD000678.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000679)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000679/QTD000679.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000680)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000680/QTD000680.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000681)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000681/QTD000681.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000682)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000682/QTD000682.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000683)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000683/QTD000683.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000684)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000684/QTD000684.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000685)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000685/QTD000685.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000686)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000686/QTD000686.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000687)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000687/QTD000687.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000040, QTD000688)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000040/QTD000688/QTD000688.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000040.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000689)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000689/QTD000689.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000690)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000690/QTD000690.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ memory T cell (QTS000041, QTD000691)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000691/QTD000691.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_memory_T_cell.bed
#
# Downloading CD4+ memory T cell (QTS000041, QTD000692)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000692/QTD000692.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_memory_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000693)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000693/QTD000693.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ memory T cell (QTS000041, QTD000694)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000694/QTD000694.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_memory_T_cell.bed
#
# Downloading CD4+ memory T cell (QTS000041, QTD000695)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000695/QTD000695.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_memory_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000696)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000696/QTD000696.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000697)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000697/QTD000697.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000698)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000698/QTD000698.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000699)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000699/QTD000699.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000700)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000700/QTD000700.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000701)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000701/QTD000701.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000702)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000702/QTD000702.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000703)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000703/QTD000703.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000704)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000704/QTD000704.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000705)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000705/QTD000705.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000706)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000706/QTD000706.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000707)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000707/QTD000707.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000708)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000708/QTD000708.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000709)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000709/QTD000709.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000710)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000710/QTD000710.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000711)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000711/QTD000711.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000712)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000712/QTD000712.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000713)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000713/QTD000713.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000714)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000714/QTD000714.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000715)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000715/QTD000715.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000716)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000716/QTD000716.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000717)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000717/QTD000717.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000718)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000718/QTD000718.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000719)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000719/QTD000719.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000720)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000720/QTD000720.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000721)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000721/QTD000721.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000722)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000722/QTD000722.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000723)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000723/QTD000723.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000724)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000724/QTD000724.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000725)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000725/QTD000725.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000726)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000726/QTD000726.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000727)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000727/QTD000727.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000728)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000728/QTD000728.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000729)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000729/QTD000729.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000730)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000730/QTD000730.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000731)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000731/QTD000731.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000732)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000732/QTD000732.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000733)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000733/QTD000733.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000734)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000734/QTD000734.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000735)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000735/QTD000735.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000736)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000736/QTD000736.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000737)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000737/QTD000737.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000738)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000738/QTD000738.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000739)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000739/QTD000739.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000740)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000740/QTD000740.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000741)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000741/QTD000741.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000742)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000742/QTD000742.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000743)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000743/QTD000743.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000744)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000744/QTD000744.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000745)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000745/QTD000745.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000746)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000746/QTD000746.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000747)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000747/QTD000747.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000748)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000748/QTD000748.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
# ❌ Failed for CD4+ T cell (QTS000041, QTD000748): HTTPConnectionPool(host='ftp.ebi.ac.uk', port=80): Max retries exceeded with url: /pub/databases/spot/eQTL/susie/QTS000041/QTD000748/QTD000748.credible_sets.tsv.gz (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f4a04a22d10>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# Downloading CD4+ T cell (QTS000041, QTD000749)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000749/QTD000749.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000750)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000750/QTD000750.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed
#
# Downloading CD4+ T cell (QTS000041, QTD000751)
#   URL: http://ftp.ebi.ac.uk/pub/databases/spot/eQTL/susie/QTS000041/QTD000751/QTD000751.credible_sets.tsv.gz
#   -> /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/QTS000041.CD4plus_T_cell.bed

# %%
import os
from collections import defaultdict
from tqdm import tqdm

# === CONFIG ===
input_dir = "/home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw"
genes_dir = os.path.join(input_dir, "genes")
os.makedirs(genes_dir, exist_ok=True)

# Collect entries per gene
gene_entries = defaultdict(list)

print("Collecting per-tissue BED entries by gene...")
for fname in tqdm(os.listdir(input_dir)):
    if not fname.endswith(".bed"):
        continue
    fpath = os.path.join(input_dir, fname)
    with open(fpath) as f:
        for line in f:
            parts = line.strip().split("\t")
            if len(parts) < 5:
                continue
            chrom, start, end, gene, sample = parts
            gene_entries[gene].append((chrom, int(start), int(end), gene, sample))

print(f"Collected entries for {len(gene_entries)} genes.")

# Write one BED per gene
for gene, entries in tqdm(gene_entries.items(), desc="Writing gene BEDs"):
    out_path = os.path.join(genes_dir, f"{gene}.bed")
    with open(out_path, "w") as f:
        for chrom, start, end, gene, sample in entries:
            f.write(f"{chrom}\t{start}\t{end}\t{gene}\t{sample}\n")

print(f"Per-gene BEDs written to {genes_dir}")
# Out:
# Collecting per-tissue BED entries by gene...
# 100%|██████████| 67/67 [00:03<00:00, 17.23it/s]
# Collected entries for 12181 genes.
# Writing gene BEDs: 100%|██████████| 12181/12181 [00:16<00:00, 740.20it/s]
# Per-gene BEDs written to /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/genes

# %%
import os
import pandas as pd
from tqdm import tqdm

genes_dir = "/home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/genes"
output_file = "/home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/eqtlcatalogue.bed"

all_lines = []

print("Merging per-gene BEDs into catalogue...")
for fname in tqdm(os.listdir(genes_dir)):
    if not fname.endswith(".bed"):
        continue
    fpath = os.path.join(genes_dir, fname)

    df = pd.read_csv(fpath, sep="\t", header=None,
                     names=["chr", "start", "end", "gene", "sample"])
    if df.empty:
        continue

    # Sort by chr and start
    df = df.sort_values(["chr", "start", "end"])

    merged = []
    cur_chr, cur_start, cur_end, cur_gene, cur_samples = None, None, None, None, set()

    for row in df.itertuples(index=False):
        chrm, start, end, gene, sample = row
        start, end = int(start), int(end)
        if cur_chr is None:
            cur_chr, cur_start, cur_end, cur_gene, cur_samples = chrm, start, end, gene, {sample}
            continue
        if chrm == cur_chr and start <= cur_end:
            cur_end = max(cur_end, end)
            cur_samples.add(sample)
        else:
            merged.append([cur_chr, cur_start, cur_end, cur_gene, ",".join(sorted(cur_samples))])
            cur_chr, cur_start, cur_end, cur_gene, cur_samples = chrm, start, end, gene, {sample}

    if cur_chr is not None:
        merged.append([cur_chr, cur_start, cur_end, cur_gene, ",".join(sorted(cur_samples))])

    all_lines.extend(merged)

# Save final merged catalogue
final_df = pd.DataFrame(all_lines, columns=["chr", "start", "end", "gene", "samples"])
final_df.to_csv(output_file, sep="\t", index=False, header=False)

print(f"Final catalogue written to {output_file}")
# Out:
# Merging per-gene BEDs into catalogue...
# 100%|██████████| 12181/12181 [00:54<00:00, 223.27it/s]
# Final catalogue written to /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/eqtlcatalogue.bed

# %%
import os
import subprocess
from tqdm import tqdm

# === CONFIG ===
genes_dir = "/home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/raw/genes"
output_file = "/home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/eqtlcatalogue.bed"
threads = 8  # adjust as needed

print("Merging per-gene BEDs with bedtools...")

tmp_files = []
for fname in tqdm(os.listdir(genes_dir)):
    if not fname.endswith(".bed"):
        continue
    fpath = os.path.join(genes_dir, fname)
    tmp_path = fpath + ".tmp"

    # Run sort + bedtools merge on each gene file
    cmd = (
        f"sort -k1,1 -k2,2n {fpath} | "
        f"bedtools merge -i - -c 4,5 -o distinct,distinct > {tmp_path}"
    )
    subprocess.run(cmd, shell=True, check=True)
    tmp_files.append(tmp_path)

# Concatenate all tmp files into final catalogue
with open(output_file, "w") as outfile:
    for tmp_path in tmp_files:
        with open(tmp_path) as infile:
            for line in infile:
                outfile.write(line)

# Clean up tmp files
for tmp_path in tmp_files:
    os.remove(tmp_path)

print(f"Final catalogue written to {output_file}")
# Out:
# Merging per-gene BEDs with bedtools...
# 100%|██████████| 12182/12182 [01:19<00:00, 153.85it/s]
# Final catalogue written to /home/andrem/GRN-project/data/input/data/pAML/benchmarks/cre2gene/eqtlcatalogue.bed
